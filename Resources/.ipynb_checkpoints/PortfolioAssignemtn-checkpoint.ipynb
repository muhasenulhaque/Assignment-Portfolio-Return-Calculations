# %%
import pandas as pd
from pathlib import Path
import csv
import numpy as np

# %%
cwd = Path.cwd()
filepath = ('./whale_returns.csv')
whale_data = pd.read_csv(filepath,index_col = 'Date', parse_dates = True)

# %%
df_whale=pd.DataFrame(whale_data)

# %%
null = df_whale.isnull()
null
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 1055                        False                   False
# 1056                        False                   False
# 1057                        False                   False
# 1058                        False                   False
# 1059                        False                   False
#
# [1060 rows x 5 columns]

# %%
df_whale_cl = df_whale.dropna()
df_whale_cl
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %%
snp_data = pd.read_csv('sp_tsx_history.csv')

# %%
snp_data = pd.read_csv('sp_tsx_history.csv', index_col = 'Date', parse_dates = True)
snp_data.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
df_snp_data = pd.DataFrame(snp_data)
#df_snp_data.columns=["Date","Close"]

# %%
#df_snp_data["Close"] = df_snp_data["Close"].str.replace("$","")
#df_snp_data["Close"] = df_snp_data["Close"].str.replace(",","")
#df_snp_data["Close"] = df_snp_data["Close"].astype("float")
#df_snp_data["Close"] = df_snp_data["Close"].astype("int")
#df_snp_data["Close"].str.isnumeric()
#df_snp_data.dtypes

# %%
df_snp_data["Close"]
# Out:
# Date
# 2012-10-01    12370.19
# 2012-10-02    12391.23
# 2012-10-03    12359.47
# 2012-10-04    12447.68
# 2012-10-05    12418.99
#                 ...
# 2019-12-20    17118.44
# 2019-12-23    17128.71
# 2019-12-24    17180.15
# 2019-12-27    17168.21
# 2019-12-30    17098.56
# Name: Close, Length: 1818, dtype: float64

# %%
df_anp_daily_returns = df_snp_data["Close"].pct_change().dropna()
df_anp_daily_returns
# Out:
# Date
# 2012-10-02    0.001701
# 2012-10-03   -0.002563
# 2012-10-04    0.007137
# 2012-10-05   -0.002305
# 2012-10-09   -0.011709
#                 ...
# 2019-12-20    0.003188
# 2019-12-23    0.000600
# 2019-12-24    0.003003
# 2019-12-27   -0.000695
# 2019-12-30   -0.004057
# Name: Close, Length: 1817, dtype: float64

# %%
std = daily_returns.std()
std.head()
# Out:
# Close    0.006637
# dtype: float64

# %%
algo_return = pd.read_csv('algo_returns.csv', index_col = 'Date', parse_dates = True)
df_algo_return =pd.DataFrame(algo_return)
df_algo_return
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
combined_data = pd.concat([df_whale_cl,df_anp_daily_returns,df_algo_return], axis='columns',join='inner')
combined_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC     Close  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.008530
# 2015-03-04                    -0.002534                0.004213 -0.003371
# 2015-03-05                     0.002355                0.006726  0.001344
# 2015-03-06                    -0.008481               -0.013098 -0.009972
# 2015-03-09                     0.005843               -0.001652 -0.006555
#
#               Algo 1    Algo 2
# Date
# 2015-03-03 -0.001942 -0.000949
# 2015-03-04 -0.008589  0.002416
# 2015-03-05 -0.000955  0.004323
# 2015-03-06 -0.004957 -0.011460
# 2015-03-09 -0.005447  0.001303

# %%
df_snp_data = df_snp_data["Close"].values().to_numeric()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19864\2360858022.py in <module>
# ----> 1 df_snp_data = df_snp_data["Close"].values().to_numeric()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
daily_returns = df_snp_data.pct_change()
daily_returns.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19864\2144851951.py in <module>
# ----> 1 daily_returns = df_snp_data.pct_change()
#       2 daily_returns.head()
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10163         shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10164         # Unsupported left operand type for / ("FrameOrSeries")
# > 10165         rs = data / shifted - 1  # type: ignore[operator]
#   10166         if freq is not None:
#   10167             # Shift method is implemented differently when freq is not None
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\arraylike.py in __truediv__(self, other)
#     114     @unpack_zerodim_and_defer("__truediv__")
#     115     def __truediv__(self, other):
# --> 116         return self._arith_method(other, operator.truediv)
#     117
#     118     @unpack_zerodim_and_defer("__rtruediv__")
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6911                     # "BlockManager"
#    6912                     right._mgr,  # type: ignore[arg-type]
# -> 6913                     array_op,
#    6914                 )
#    6915             return type(self)(bm)
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~\anaconda3\envs\alpacaenv\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     110         # See GH#5284, GH#5035, GH#19448 for historical reference
#     111         if mask.any():
# --> 112             result[mask] = op(xrav[mask], yrav[mask])
#     113
#     114     else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
pnl_diff = {}
with open(filepath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter = ',')
    header = next(csvreader)
    first_row = next(csvreader)
    prev_pnl = int(first_row[1])
    for row in csvreader:
        diff = int(row[1]) - prev_pnl
        prev_pnl = int(row[1])
        pnl_diff[row[0]] = diff
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19240\686873291.py in <module>
#       4     header = next(csvreader)
#       5     first_row = next(csvreader)
# ----> 6     prev_pnl = int(first_row[1])
#       7     for row in csvreader:
#       8         diff = int(row[1]) - prev_pnl
#
# ValueError: invalid literal for int() with base 10: ''

# %%
 element = []
for elements in df_snp_data["Close"]
  csvreader = csv.reader(csvfile, delimiter = ',')
    header = next(csvreader)
    first_row = next(csvreader)
    prev_pnl = int(first_row[1])
    changes = df_snp_data["Canges",row[1]]-df_snp_data["Canges",row[0]]
